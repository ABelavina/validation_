# %% [markdown]
# Ваша задача - написать функцию, которая рассчитывает для каждой переменной значение индекса CSI (characteristic stability index, иногда его еще называют PSI - population stability index).
#
# На вход функции должны подаваться два датасета. В одном из них - значения независимых переменных какой-то ML-модели на выборке разработки, во втором - значения тех же переменных на тестовой выборке. Скачаем эти датасеты:

# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv('https://docs.google.com/uc?id=1--bDvtpHmLmu7JIx5atDZedzkLDe3rzA&export=download')
X_test = pd.read_csv('https://docs.google.com/uc?id=1-2ySFsi0rft_V1lPBNjUswOinHm6uDbk&export=download')

# %% [markdown]
# СSI - это показатель стабильности эмпирического распределения, основная идея которого - разбить значения переменной на категории и сравнить долю наблюдений, попавших в каждую категорию на тестовой выборке с долей, попавших в эту категорию на бенчмарке (на выборке разработки).
# Формула расчета индекса CSI:
#
# \begin{align}
# CSI = \sum_{i=1}^K((val_i - dev_i)×ln(\frac{val_i}{dev_i}))
#   \end{align}
# где K - количество категорий, на которые разбиваются значения переменных, *valᵢ* - доля наблюдений, попавших в категорию i на тестовой выборке, *devᵢ* - доля наблюдений, попавщих в категорию i на выборке разработки.
#
# Дополнительные требования:
#
# *   Функция должна возвращать значение индекса CSI, дополнительно можно реализовать вывод долей наблюдений по категориям в каждой из выборок.
# *   Числовые переменные функция должна разбивать на K категорий, подбирая границы категорий так, чтобы на выборке разработки доли наблюдений в них были одинаковы. K необходимо вынести в аргументы функции.
# *   Для категориальных переменных в качестве категорий используются уникальные значения.
# *   Пропущенные значения нужно выносить в отдельную категорию.

# %%
# Функция для поиска наибольшего делителя, не большее, чем max_block
def divisor(n, max_block=24): 
  i=2
  pre_i=1
  while((i<max_block)&(n>=i)): 
    while((n%i!=0)&(n>=i)&(i<max_block)):
      i+=1
    if(n%i==0):
      pre_i=i
      i+=1
  if(n%i==0):
    return i
  else:
    if(pre_i==1):
       return divisor(n+1)
    else:
       return pre_i

# %%
# Функция для деления на категории по одинаковым долям
def K_share(val, dev, num_bins=0):
   val=val[~np.isnan(val)]
   dev=dev[~np.isnan(dev)]
   count_dev=len(np.unique(dev))
   dev=np.append(dev,10**100)
   dev.sort()
   if(num_bins==0):
     num_bins=divisor(count_dev)
   k = [np.unique(dev)[i] for i in range(0, count_dev+1, int(count_dev/num_bins))]
   dev=dev[:-1]
   if(val.min()<dev.min()):
     k.append(val.min())
   if(val.max()>dev.max()):
     k.append(val.max())
   else:
     k.sort()
     k[-1]=dev.max()
   k.sort()
   k[0] -= 0.01
   k[-1] += 0.01
   return k

# %% [markdown]
# Не определилась как необходимо делить на категории из условия, поэтому реализовала две функции: для деления на равные доли по выборке разработки и для деления на равные расстояния по всем показаниям.

# %%
# Функция для деления на категории по одинаковым расстояниям
def K(val, dev, num_bins=0):
   val=val[~np.isnan(val)]
   dev=dev[~np.isnan(dev)]
   count_dev=len(np.unique(dev))
   if(num_bins==0):
     num_bins=divisor(count_dev)
   min = np.array([val.min(), dev.min()]).min()
   max = np.array([val.max(), dev.max()]).max()
   k = [min + (max - min)*(i)/num_bins for i in range(num_bins+1)]
   k[0] = min - 0.01
   k[-1] = max + 0.01
   return k

# %%
def CSI(val, dev, k):
  def calc_csi(val_i, dev_i):     #расчет CSI
    if(dev_i==0):
      dev_i=10**(-4)
    if(val_i==0):
      val_i=10**(-4)
    return ((val_i - dev_i) * np.log(val_i / dev_i))
 
  def count_i(X, start, end):  #Кол-во элементов, входящих в интервал
    i=0
    count_i=0
    while (X[i]<end):
      if(X[i]>=start):
        count_i+=1
      if(i<len(X)-1):
        i+=1
      else:
        return count_i
    return count_i

  sum_val_i=0
  sum_dev_i=0
  count_val=len(val)
  count_dev=len(dev)
  csi=np.array([])

  val_nan=len(val[np.isnan(val)])/count_val
  dev_nan=len(dev[np.isnan(dev)])/count_dev
  csi=np.append(csi, calc_csi(val_nan, dev_nan))

  val=val[~np.isnan(val)]
  dev=dev[~np.isnan(dev)]
  val.sort()
  dev.sort()

  for i in range(len(k)-1):
    val_i=count_i(val, k[i], k[i+1])/count_val
    sum_val_i+=val_i
    dev_i=count_i(dev, k[i], k[i+1])/count_dev
    print('Доля на тесте val_'+str(i),'{:<20.2%}'.format(val_i), 'Доля на разработке dev_'+str(i), '{:.2%}'.format(dev_i))
    sum_dev_i+=dev_i
    csi=np.append(csi, calc_csi(val_i, dev_i))
    
  print('{:<46}'.format('\nСумма не пустых на тесте sum_val_i ='), '{:.2%}'.format(sum_val_i))
  print('{:<45}'.format('Сумма не пустых на разработке sum_dev_i ='), '{:.2%}'.format(sum_dev_i))
  print('{:<45}'.format('Сумма пустых на тесте val_nan ='),  '{:.2%}'.format(val_nan))
  print('{:<45}'.format('Сумма пустых на разработке dev_nan ='),  '{:.2%}'.format(dev_nan))
  return csi.sum()

# %%
# Кодирование категорий
def code_categ(values):
  dict_code_categ={}
  i=0
  for j in set(values):
    dict_code_categ[j]=i
    i+=1
  return dict_code_categ

dict_code_categ=code_categ(np.append(X_train['1'].values,X_test['1'].values))
X_test['1'] = X_test['1'].replace(dict_code_categ)
X_train['1'] = X_train['1'].replace(dict_code_categ)

dict_code_categ=code_categ(np.append(X_train['3'].values,X_test['3'].values))
X_test['3'] = X_test['3'].replace(dict_code_categ)
X_train['3'] = X_train['3'].replace(dict_code_categ)

dict_code_categ=code_categ(np.append(X_train['7'].values,X_test['7'].values))
X_test['7'] = X_test['7'].replace(dict_code_categ)
X_train['7'] = X_train['7'].replace(dict_code_categ)

# %%
#CSI при делении на равные доли
csi_arr=[]
for i in X_train.columns:
  print('\n\n', i,':')
  csi=CSI(np.array(X_train[i]), np.array(X_test[i]), K_share(np.array(X_train[i]), np.array(X_test[i])))
  csi_arr.append(csi)
  print('CSI=', csi)
# Out:
#  0 :
# Доля на тесте val_0 10.80%               Доля на разработке dev_0 11.87%
# Доля на тесте val_1 13.60%               Доля на разработке dev_1 11.87%
# Доля на тесте val_2 10.80%               Доля на разработке dev_2 11.87%
# Доля на тесте val_3 12.80%               Доля на разработке dev_3 11.87%
# Доля на тесте val_4 10.40%               Доля на разработке dev_4 11.87%
# Доля на тесте val_5 10.00%               Доля на разработке dev_5 11.87%
# Доля на тесте val_6 13.20%               Доля на разработке dev_6 11.87%
# Доля на тесте val_7 13.60%               Доля на разработке dev_7 11.87%
#
# Сумма не пустых на тесте sum_val_i =          95.20%
# Сумма не пустых на разработке sum_dev_i =     94.93%
# Сумма пустых на тесте val_nan =               4.80%
# Сумма пустых на разработке dev_nan =          5.07%
# CSI= 0.01413596470964694
#
#
#  1 :
# Доля на тесте val_0 3.60%                Доля на разработке dev_0 4.40%
# Доля на тесте val_1 24.00%               Доля на разработке dev_1 24.27%
# Доля на тесте val_2 24.40%               Доля на разработке dev_2 24.40%
# Доля на тесте val_3 23.20%               Доля на разработке dev_3 22.00%
# Доля на тесте val_4 24.80%               Доля на разработке dev_4 24.93%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 0.0022792989548173336
#
#
#  2 :
# Доля на тесте val_0 4.00%                Доля на разработке dev_0 4.13%
# Доля на тесте val_1 4.00%                Доля на разработке dev_1 4.13%
# Доля на тесте val_2 0.80%                Доля на разработке dev_2 4.13%
# Доля на тесте val_3 3.60%                Доля на разработке dev_3 4.13%
# Доля на тесте val_4 3.20%                Доля на разработке dev_4 4.13%
# Доля на тесте val_5 1.60%                Доля на разработке dev_5 4.13%
# Доля на тесте val_6 4.40%                Доля на разработке dev_6 4.13%
# Доля на тесте val_7 5.20%                Доля на разработке dev_7 4.13%
# Доля на тесте val_8 4.40%                Доля на разработке dev_8 4.13%
# Доля на тесте val_9 4.80%                Доля на разработке dev_9 4.13%
# Доля на тесте val_10 5.20%                Доля на разработке dev_10 4.13%
# Доля на тесте val_11 3.20%                Доля на разработке dev_11 4.13%
# Доля на тесте val_12 4.80%                Доля на разработке dev_12 4.13%
# Доля на тесте val_13 4.80%                Доля на разработке dev_13 4.13%
# Доля на тесте val_14 4.80%                Доля на разработке dev_14 4.13%
# Доля на тесте val_15 3.60%                Доля на разработке dev_15 4.13%
# Доля на тесте val_16 2.80%                Доля на разработке dev_16 4.13%
# Доля на тесте val_17 3.60%                Доля на разработке dev_17 4.13%
# Доля на тесте val_18 5.20%                Доля на разработке dev_18 4.13%
# Доля на тесте val_19 4.80%                Доля на разработке dev_19 4.13%
# Доля на тесте val_20 5.60%                Доля на разработке dev_20 4.13%
# Доля на тесте val_21 5.60%                Доля на разработке dev_21 4.13%
# Доля на тесте val_22 2.80%                Доля на разработке dev_22 4.13%
# Доля на тесте val_23 0.40%                Доля на разработке dev_23 0.00%
#
# Сумма не пустых на тесте sum_val_i =          93.20%
# Сумма не пустых на разработке sum_dev_i =     95.07%
# Сумма пустых на тесте val_nan =               6.80%
# Сумма пустых на разработке dev_nan =          4.93%
# CSI= 0.13819443355450284
#
#
#  3 :
# Доля на тесте val_0 7.60%                Доля на разработке dev_0 9.33%
# Доля на тесте val_1 91.20%               Доля на разработке dev_1 90.67%
# Доля на тесте val_2 1.20%                Доля на разработке dev_2 0.00%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 0.06056346126257583
#
#
#  4 :
# Доля на тесте val_0 48.40%               Доля на разработке dev_0 47.87%
# Доля на тесте val_1 46.80%               Доля на разработке dev_1 47.87%
#
# Сумма не пустых на тесте sum_val_i =          95.20%
# Сумма не пустых на разработке sum_dev_i =     95.73%
# Сумма пустых на тесте val_nan =               4.80%
# Сумма пустых на разработке dev_nan =          4.27%
# CSI= 0.0009276576612148333
#
#
#  5 :
# Доля на тесте val_0 4.80%                Доля на разработке dev_0 4.13%
# Доля на тесте val_1 8.00%                Доля на разработке dev_1 4.13%
# Доля на тесте val_2 2.00%                Доля на разработке dev_2 4.13%
# Доля на тесте val_3 4.40%                Доля на разработке dev_3 4.13%
# Доля на тесте val_4 2.80%                Доля на разработке dev_4 4.13%
# Доля на тесте val_5 3.20%                Доля на разработке dev_5 4.13%
# Доля на тесте val_6 5.60%                Доля на разработке dev_6 4.13%
# Доля на тесте val_7 4.80%                Доля на разработке dev_7 4.13%
# Доля на тесте val_8 4.40%                Доля на разработке dev_8 4.13%
# Доля на тесте val_9 7.60%                Доля на разработке dev_9 4.13%
# Доля на тесте val_10 3.60%                Доля на разработке dev_10 4.13%
# Доля на тесте val_11 3.60%                Доля на разработке dev_11 4.13%
# Доля на тесте val_12 4.80%                Доля на разработке dev_12 4.13%
# Доля на тесте val_13 7.20%                Доля на разработке dev_13 4.13%
# Доля на тесте val_14 4.80%                Доля на разработке dev_14 4.13%
# Доля на тесте val_15 3.60%                Доля на разработке dev_15 4.13%
# Доля на тесте val_16 3.20%                Доля на разработке dev_16 4.13%
# Доля на тесте val_17 2.80%                Доля на разработке dev_17 4.13%
# Доля на тесте val_18 1.60%                Доля на разработке dev_18 4.13%
# Доля на тесте val_19 2.00%                Доля на разработке dev_19 4.13%
# Доля на тесте val_20 4.40%                Доля на разработке dev_20 4.13%
# Доля на тесте val_21 2.80%                Доля на разработке dev_21 4.13%
# Доля на тесте val_22 4.40%                Доля на разработке dev_22 4.13%
#
# Сумма не пустых на тесте sum_val_i =          96.40%
# Сумма не пустых на разработке sum_dev_i =     95.07%
# Сумма пустых на тесте val_nan =               3.60%
# Сумма пустых на разработке dev_nan =          4.93%
# CSI= 0.15456053319035667
#
#
#  6 :
# Доля на тесте val_0 10.40%               Доля на разработке dev_0 13.47%
# Доля на тесте val_1 12.00%               Доля на разработке dev_1 13.47%
# Доля на тесте val_2 9.60%                Доля на разработке dev_2 13.47%
# Доля на тесте val_3 14.80%               Доля на разработке dev_3 13.47%
# Доля на тесте val_4 17.60%               Доля на разработке dev_4 13.47%
# Доля на тесте val_5 14.40%               Доля на разработке dev_5 13.47%
# Доля на тесте val_6 16.00%               Доля на разработке dev_6 13.47%
#
# Сумма не пустых на тесте sum_val_i =          94.80%
# Сумма не пустых на разработке sum_dev_i =     94.27%
# Сумма пустых на тесте val_nan =               5.20%
# Сумма пустых на разработке dev_nan =          5.73%
# CSI= 0.04053862438394766
#
#
#  7 :
# Доля на тесте val_0 98.40%               Доля на разработке dev_0 5.07%
# Доля на тесте val_1 0.00%                Доля на разработке dev_1 93.47%
# Доля на тесте val_2 1.60%                Доля на разработке dev_2 1.47%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 11.313249307264917
#
#
#  8 :
# Доля на тесте val_0 18.00%               Доля на разработке dev_0 19.33%
# Доля на тесте val_1 12.00%               Доля на разработке dev_1 19.33%
# Доля на тесте val_2 20.40%               Доля на разработке dev_2 19.33%
# Доля на тесте val_3 25.60%               Доля на разработке dev_3 19.33%
# Доля на тесте val_4 18.80%               Доля на разработке dev_4 19.33%
#
# Сумма не пустых на тесте sum_val_i =          94.80%
# Сумма не пустых на разработке sum_dev_i =     96.67%
# Сумма пустых на тесте val_nan =               5.20%
# Сумма пустых на разработке dev_nan =          3.33%
# CSI= 0.0625444540452426
#
#
#  9 :
# Доля на тесте val_0 0.80%                Доля на разработке dev_0 0.00%
# Доля на тесте val_1 15.20%               Доля на разработке dev_1 11.87%
# Доля на тесте val_2 12.80%               Доля на разработке dev_2 11.87%
# Доля на тесте val_3 10.80%               Доля на разработке dev_3 11.87%
# Доля на тесте val_4 9.60%                Доля на разработке dev_4 11.87%
# Доля на тесте val_5 12.40%               Доля на разработке dev_5 11.87%
# Доля на тесте val_6 10.80%               Доля на разработке dev_6 11.87%
# Доля на тесте val_7 11.60%               Доля на разработке dev_7 11.87%
# Доля на тесте val_8 12.00%               Доля на разработке dev_8 11.87%
#
# Сумма не пустых на тесте sum_val_i =          96.00%
# Сумма не пустых на разработке sum_dev_i =     94.93%
# Сумма пустых на тесте val_nan =               4.00%
# Сумма пустых на разработке dev_nan =          5.07%
# CSI= 0.053222166337642283

# %%
#CSI при делении на равные расстояния
csi_arr_K=[]
for i in X_train.columns:
  print('\n\n', i,':')
  csi=CSI(np.array(X_train[i]), np.array(X_test[i]), K(np.array(X_train[i]), np.array(X_test[i])))
  csi_arr_K.append(csi)
  print('CSI=', csi)
# Out:
#  0 :
# Доля на тесте val_0 1.60%                Доля на разработке dev_0 1.87%
# Доля на тесте val_1 7.20%                Доля на разработке dev_1 7.07%
# Доля на тесте val_2 17.60%               Доля на разработке dev_2 18.27%
# Доля на тесте val_3 26.00%               Доля на разработке dev_3 28.00%
# Доля на тесте val_4 22.40%               Доля на разработке dev_4 21.60%
# Доля на тесте val_5 13.60%               Доля на разработке dev_5 12.93%
# Доля на тесте val_6 6.40%                Доля на разработке dev_6 4.40%
# Доля на тесте val_7 0.40%                Доля на разработке dev_7 0.80%
#
# Сумма не пустых на тесте sum_val_i =          95.20%
# Сумма не пустых на разработке sum_dev_i =     94.93%
# Сумма пустых на тесте val_nan =               4.80%
# Сумма пустых на разработке dev_nan =          5.07%
# CSI= 0.013202667807936682
#
#
#  1 :
# Доля на тесте val_0 3.60%                Доля на разработке dev_0 4.40%
# Доля на тесте val_1 24.00%               Доля на разработке dev_1 24.27%
# Доля на тесте val_2 24.40%               Доля на разработке dev_2 24.40%
# Доля на тесте val_3 23.20%               Доля на разработке dev_3 22.00%
# Доля на тесте val_4 24.80%               Доля на разработке dev_4 24.93%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 0.0022792989548173336
#
#
#  2 :
# Доля на тесте val_0 0.00%                Доля на разработке dev_0 0.40%
# Доля на тесте val_1 0.40%                Доля на разработке dev_1 0.40%
# Доля на тесте val_2 0.80%                Доля на разработке dev_2 0.93%
# Доля на тесте val_3 5.20%                Доля на разработке dev_3 4.13%
# Доля на тесте val_4 2.40%                Доля на разработке dev_4 6.13%
# Доля на тесте val_5 4.80%                Доля на разработке dev_5 6.40%
# Доля на тесте val_6 3.60%                Доля на разработке dev_6 7.60%
# Доля на тесте val_7 4.40%                Доля на разработке dev_7 3.60%
# Доля на тесте val_8 4.40%                Доля на разработке dev_8 2.80%
# Доля на тесте val_9 6.40%                Доля на разработке dev_9 5.87%
# Доля на тесте val_10 6.80%                Доля на разработке dev_10 5.33%
# Доля на тесте val_11 6.00%                Доля на разработке dev_11 6.40%
# Доля на тесте val_12 7.20%                Доля на разработке dev_12 6.80%
# Доля на тесте val_13 5.20%                Доля на разработке dev_13 4.40%
# Доля на тесте val_14 3.60%                Доля на разработке dev_14 3.87%
# Доля на тесте val_15 4.00%                Доля на разработке dev_15 5.20%
# Доля на тесте val_16 3.60%                Доля на разработке dev_16 4.27%
# Доля на тесте val_17 7.60%                Доля на разработке dev_17 5.07%
# Доля на тесте val_18 5.60%                Доля на разработке dev_18 5.73%
# Доля на тесте val_19 6.00%                Доля на разработке dev_19 3.73%
# Доля на тесте val_20 2.80%                Доля на разработке dev_20 3.47%
# Доля на тесте val_21 0.80%                Доля на разработке dev_21 1.33%
# Доля на тесте val_22 1.60%                Доля на разработке dev_22 1.20%
#
# Сумма не пустых на тесте sum_val_i =          93.20%
# Сумма не пустых на разработке sum_dev_i =     95.07%
# Сумма пустых на тесте val_nan =               6.80%
# Сумма пустых на разработке dev_nan =          4.93%
# CSI= 0.1380671624749767
#
#
#  3 :
# Доля на тесте val_0 7.60%                Доля на разработке dev_0 9.33%
# Доля на тесте val_1 92.40%               Доля на разработке dev_1 90.67%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 0.0038892737040657067
#
#
#  4 :
# Доля на тесте val_0 56.40%               Доля на разработке dev_0 53.87%
# Доля на тесте val_1 38.80%               Доля на разработке dev_1 41.87%
#
# Сумма не пустых на тесте sum_val_i =          95.20%
# Сумма не пустых на разработке sum_dev_i =     95.73%
# Сумма пустых на тесте val_nan =               4.80%
# Сумма пустых на разработке dev_nan =          4.27%
# CSI= 0.004125232525584619
#
#
#  5 :
# Доля на тесте val_0 0.00%                Доля на разработке dev_0 0.13%
# Доля на тесте val_1 0.00%                Доля на разработке dev_1 0.00%
# Доля на тесте val_2 0.00%                Доля на разработке dev_2 0.13%
# Доля на тесте val_3 0.80%                Доля на разработке dev_3 1.33%
# Доля на тесте val_4 2.80%                Доля на разработке dev_4 1.20%
# Доля на тесте val_5 3.60%                Доля на разработке dev_5 2.67%
# Доля на тесте val_6 6.80%                Доля на разработке dev_6 4.80%
# Доля на тесте val_7 7.20%                Доля на разработке dev_7 7.20%
# Доля на тесте val_8 6.40%                Доля на разработке dev_8 9.33%
# Доля на тесте val_9 12.00%               Доля на разработке dev_9 10.40%
# Доля на тесте val_10 10.00%               Доля на разработке dev_10 6.40%
# Доля на тесте val_11 8.80%                Доля на разработке dev_11 8.80%
# Доля на тесте val_12 12.00%               Доля на разработке dev_12 8.40%
# Доля на тесте val_13 7.60%                Доля на разработке dev_13 9.20%
# Доля на тесте val_14 4.00%                Доля на разработке dev_14 7.60%
# Доля на тесте val_15 4.00%                Доля на разработке dev_15 6.80%
# Доля на тесте val_16 4.40%                Доля на разработке dev_16 4.00%
# Доля на тесте val_17 2.00%                Доля на разработке dev_17 3.33%
# Доля на тесте val_18 1.60%                Доля на разработке dev_18 0.80%
# Доля на тесте val_19 1.60%                Доля на разработке dev_19 1.07%
# Доля на тесте val_20 0.00%                Доля на разработке dev_20 0.53%
# Доля на тесте val_21 0.40%                Доля на разработке dev_21 0.53%
# Доля на тесте val_22 0.40%                Доля на разработке dev_22 0.40%
#
# Сумма не пустых на тесте sum_val_i =          96.40%
# Сумма не пустых на разработке sum_dev_i =     95.07%
# Сумма пустых на тесте val_nan =               3.60%
# Сумма пустых на разработке dev_nan =          4.93%
# CSI= 0.15601759995556452
#
#
#  6 :
# Доля на тесте val_0 2.00%                Доля на разработке dev_0 1.47%
# Доля на тесте val_1 6.80%                Доля на разработке dev_1 8.53%
# Доля на тесте val_2 16.80%               Доля на разработке dev_2 22.40%
# Доля на тесте val_3 30.40%               Доля на разработке dev_3 30.13%
# Доля на тесте val_4 24.00%               Доля на разработке dev_4 19.60%
# Доля на тесте val_5 12.00%               Доля на разработке dev_5 9.47%
# Доля на тесте val_6 2.80%                Доля на разработке dev_6 2.67%
#
# Сумма не пустых на тесте sum_val_i =          94.80%
# Сумма не пустых на разработке sum_dev_i =     94.27%
# Сумма пустых на тесте val_nan =               5.20%
# Сумма пустых на разработке dev_nan =          5.73%
# CSI= 0.037227660939210316
#
#
#  7 :
# Доля на тесте val_0 98.40%               Доля на разработке dev_0 5.07%
# Доля на тесте val_1 0.00%                Доля на разработке dev_1 93.47%
# Доля на тесте val_2 1.60%                Доля на разработке dev_2 1.47%
#
# Сумма не пустых на тесте sum_val_i =          100.00%
# Сумма не пустых на разработке sum_dev_i =     100.00%
# Сумма пустых на тесте val_nan =               0.00%
# Сумма пустых на разработке dev_nan =          0.00%
# CSI= 11.313249307264917
#
#
#  8 :
# Доля на тесте val_0 0.40%                Доля на разработке dev_0 0.80%
# Доля на тесте val_1 15.20%               Доля на разработке dev_1 16.53%
# Доля на тесте val_2 41.60%               Доля на разработке dev_2 44.53%
# Доля на тесте val_3 31.60%               Доля на разработке dev_3 28.13%
# Доля на тесте val_4 6.00%                Доля на разработке dev_4 6.67%
#
# Сумма не пустых на тесте sum_val_i =          94.80%
# Сумма не пустых на разработке sum_dev_i =     96.67%
# Сумма пустых на тесте val_nan =               5.20%
# Сумма пустых на разработке dev_nan =          3.33%
# CSI= 0.018923947603398803
#
#
#  9 :
# Доля на тесте val_0 0.80%                Доля на разработке dev_0 0.13%
# Доля на тесте val_1 1.20%                Доля на разработке dev_1 1.20%
# Доля на тесте val_2 13.20%               Доля на разработке dev_2 8.13%
# Доля на тесте val_3 25.60%               Доля на разработке dev_3 28.27%
# Доля на тесте val_4 30.00%               Доля на разработке dev_4 33.33%
# Доля на тесте val_5 21.20%               Доля на разработке dev_5 19.47%
# Доля на тесте val_6 3.60%                Доля на разработке dev_6 3.73%
# Доля на тесте val_7 0.40%                Доля на разработке dev_7 0.67%
#
# Сумма не пустых на тесте sum_val_i =          96.00%
# Сумма не пустых на разработке sum_dev_i =     94.93%
# Сумма пустых на тесте val_nan =               4.00%
# Сумма пустых на разработке dev_nan =          5.07%
# CSI= 0.04804529789316064

# %%
print(csi_arr)  #CSI при делении на равные доли
print(csi_arr_K)#CSI при делении на равные расстояния
# Out:
# [0.01413596470964694, 0.0022792989548173336, 0.13819443355450284, 0.06056346126257583, 0.0009276576612148333, 0.15456053319035667, 0.04053862438394766, 11.313249307264917, 0.0625444540452426, 0.053222166337642283]
# [0.013202667807936682, 0.0022792989548173336, 0.1380671624749767, 0.0038892737040657067, 0.004125232525584619, 0.15601759995556452, 0.037227660939210316, 11.313249307264917, 0.018923947603398803, 0.04804529789316064]
